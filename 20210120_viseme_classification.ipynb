# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenalli/Tensorflow/blob/main/20210120_viseme_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone 'https://github.com/Magicboomliu/Viseme-Classification'
# Out:
# Cloning into 'Viseme-Classification'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 14753 (delta 7), reused 0 (delta 0), pack-reused 14737
# Receiving objects: 100% (14753/14753), 959.54 MiB | 25.55 MiB/s, done.
# Resolving deltas: 100% (2145/2145), done.
# Checking out files: 100% (14725/14725), done.

# %%
# %cd Viseme-Classification/
# Out:
# /content/Viseme-Classification/Viseme-Classification

# %%
# %ls
# Out:
#  00000.png  'Data Training'/   LICENSE   README.md

# %%
# %cd Data\ Training
# Out:
# /content/Viseme-Classification/Viseme-Classification/Data Training

# %%
# !python example.py
# Out:
# Loading the PixelShift Data...
# tcmalloc: large alloc 1075224576 bytes == 0xc3e2a000 @  0x7f1af190b1e7 0x7f1aef48b41e 0x7f1aef4dbc2b 0x7f1aef4dbcc8 0x7f1aef582fb0 0x7f1aef5836dc 0x7f1aef5837fd 0x566f73 0x59fd0e 0x7f1aef4c8ea7 0x50a12f 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x588d41 0x59fd0e 0x7f1aef4c8ea7 0x50a12f 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# tcmalloc: large alloc 1208426496 bytes == 0x103fb6000 @  0x7f1af190b1e7 0x7f1aef48b41e 0x7f1aef4dbc2b 0x7f1aef4dbcc8 0x7f1aef582fb0 0x7f1aef5836dc 0x7f1aef5837fd 0x566f73 0x59fd0e 0x7f1aef4c8ea7 0x50a12f 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x588d41 0x59fd0e 0x7f1aef4c8ea7 0x50a12f 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03
# n
# ...

# %%
# !python extract_mfcc.py
# Out:
# tcmalloc: large alloc 2317099008 bytes == 0x332a000 @  0x7f5493fff1e7 0x59211c 0x4cddd0 0x5669e2 0x5a4cd1 0x4ddd76 0x5eae15 0x4debf7 0x5ebace 0x50a25a 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f5493bfcbf7 0x5b259a
# tcmalloc: large alloc 2317099008 bytes == 0x8d4ec000 @  0x7f5493fff1e7 0x59211c 0x5eadd6 0x4debf7 0x5ebace 0x50a25a 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x50ad03 0x634e72 0x634f27 0x6386df 0x639281 0x4b0dc0 0x7f5493bfcbf7 0x5b259a
# (1131395, 256)
# (1131395, 15)
# 21753
# 21753
# 14
# useful wav data set:  (21753, 256)
# useful wav label set (21753,)
# (21753, 257)
# Wav Frame data After FFT： (21753, 257)
# (21753, 40)
# Wav Frame data After FBanks： (21753, 40)
# Wav Frams's MFCC features (21753, 13)
# Finish 0
# MFCC Total is  (21753, 13)
# Label Total is  (21753,)

# %%
# !python rebalance_samples.py

# %%
# !python svm.py
# Out:
# Beigin Training!
# Training is Done!
# Training accuracy is  0.8671328671328671
# <Figure size 640x480 with 2 Axes>

# %%
# !python dnn.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 504/3000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2111 - accuracy: 0.9724 - val_loss: 0.5151 - val_accuracy: 0.8718
# Epoch 505/3000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2057 - accuracy: 0.9809 - val_loss: 0.5137 - val_accuracy: 0.8765
# Epoch 506/3000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2134 - accuracy: 0.9735 - val_loss: 0.5166 - val_accuracy: 0.8753
# Epoch 507/3000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2103 - accuracy: 0.9740 - val_loss: 0.5213 - val_accuracy: 0.8718
# Epoch 508/3000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.2040 - accuracy: 0.9764 - val_loss: 0.5173 - val_accuracy: 0.8730
# Epoch 509/3000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2031 - accuracy: 0.9788 - val_loss: 0.5162 - val_accuracy: 0.8718
# Epoch 510/3000
# ...
